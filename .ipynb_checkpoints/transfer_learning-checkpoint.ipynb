# %% [markdown]
# # Convolutional Neural Networks
#
# ## Project: Write an Algorithm for Landmark Classification
#
#
# ### Transfer learning
#
# In the previous notebook we have trained our own CNN and we got a certain performance. Let's see how hard it is to match that performance with transfer learning.
#
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 0: Setting up
#
# The following cells make sure that your environment is setup correctly and check that your GPU is available and ready to go. You have to execute them every time you restart your notebook.

# %%
# Install requirements
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: opencv-python-headless==4.5.3.56 in c:\miniconda\envs\udacity\lib\site-packages (from -r requirements.txt (line 1)) (4.5.3.56)
# Requirement already satisfied: matplotlib==3.4.3 in c:\miniconda\envs\udacity\lib\site-packages (from -r requirements.txt (line 2)) (3.4.3)
# Requirement already satisfied: numpy==1.21.2 in c:\miniconda\envs\udacity\lib\site-packages (from -r requirements.txt (line 3)) (1.21.2)
# Requirement already satisfied: pillow==7.0.0 in c:\miniconda\envs\udacity\lib\site-packages (from -r requirements.txt (line 4)) (7.0.0)
# Requirement already satisfied: bokeh==2.1.1 in c:\miniconda\envs\udacity\lib\site-packages (from -r requirements.txt (line 5)) (2.1.1)
# Requirement already satisfied: torch==1.11.0 in c:\miniconda\envs\udacity\lib\site-packages (from -r requirements.txt (line 6)) (1.11.0)
# Requirement already satisfied: torchvision==0.12.0 in c:\miniconda\envs\udacity\lib\site-packages (from -r requirements.txt (line 7)) (0.12.0)
# Requirement already satisfied: tqdm==4.63.0 in c:\miniconda\envs\udacity\lib\site-packages (from -r requirements.txt (line 8)) (4.63.0)
# Requirement already satisfied: ipywidgets==7.6.5 in c:\miniconda\envs\udacity\lib\site-packages (from -r requirements.txt (line 9)) (7.6.5)
# Requirement already satisfied: livelossplot==0.5.4 in c:\miniconda\envs\udacity\lib\site-packages (from -r requirements.txt (line 10)) (0.5.4)
# Requirement already satisfied: pytest==7.1.1 in c:\miniconda\envs\udacity\lib\site-packages (from -r requirements.txt (line 11)) (7.1.1)
# Requirement already satisfied: pandas==1.3.5 in c:\miniconda\envs\udacity\lib\site-packages (from -r requirements.txt (line 12)) (1.3.5)
# Requirement already satisfied: seaborn==0.11.2 in c:\miniconda\envs\udacity\lib\site-packages (from -r requirements.txt (line 13)) (0.11.2)
# Requirement already satisfied: cycler>=0.10 in c:\miniconda\envs\udacity\lib\site-packages (from matplotlib==3.4.3->-r requirements.txt (line 2)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\miniconda\envs\udacity\lib\site-packages (from matplotlib==3.4.3->-r requirements.txt (line 2)) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\miniconda\envs\udacity\lib\site-packages (from matplotlib==3.4.3->-r requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\miniconda\envs\udacity\lib\site-packages (from matplotlib==3.4.3->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: Jinja2>=2.7 in c:\miniconda\envs\udacity\lib\site-packages (from bokeh==2.1.1->-r requirements.txt (line 5)) (3.1.2)
# Requirement already satisfied: tornado>=5.1 in c:\miniconda\envs\udacity\lib\site-packages (from bokeh==2.1.1->-r requirements.txt (line 5)) (6.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in c:\miniconda\envs\udacity\lib\site-packages (from bokeh==2.1.1->-r requirements.txt (line 5)) (4.4.0)
# Requirement already satisfied: packaging>=16.8 in c:\miniconda\envs\udacity\lib\site-packages (from bokeh==2.1.1->-r requirements.txt (line 5)) (23.1)
# Requirement already satisfied: PyYAML>=3.10 in c:\miniconda\envs\udacity\lib\site-packages (from bokeh==2.1.1->-r requirements.txt (line 5)) (6.0.1)
# Requirement already satisfied: requests in c:\miniconda\envs\udacity\lib\site-packages (from torchvision==0.12.0->-r requirements.txt (line 7)) (2.28.1)
# Requirement already satisfied: colorama in c:\miniconda\envs\udacity\lib\site-packages (from tqdm==4.63.0->-r requirements.txt (line 8)) (0.4.6)
# Requirement already satisfied: traitlets>=4.3.1 in c:\miniconda\envs\udacity\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (5.9.0)
# Requirement already satisfied: ipython>=4.0.0 in c:\miniconda\envs\udacity\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (7.34.0)
# Requirement already satisfied: ipykernel>=4.5.1 in c:\miniconda\envs\udacity\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (6.16.2)
# Requirement already satisfied: nbformat>=4.2.0 in c:\miniconda\envs\udacity\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (5.8.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in c:\miniconda\envs\udacity\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in c:\miniconda\envs\udacity\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (3.0.8)
# Requirement already satisfied: widgetsnbextension~=3.5.0 in c:\miniconda\envs\udacity\lib\site-packages (from ipywidgets==7.6.5->-r requirements.txt (line 9)) (3.5.2)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\miniconda\envs\udacity\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (1.2.0)
# Requirement already satisfied: iniconfig in c:\miniconda\envs\udacity\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (2.0.0)
# Requirement already satisfied: py>=1.8.2 in c:\miniconda\envs\udacity\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (1.11.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\miniconda\envs\udacity\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (23.1.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\miniconda\envs\udacity\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (2.0.1)
# Requirement already satisfied: atomicwrites>=1.0 in c:\miniconda\envs\udacity\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (1.4.1)
# Requirement already satisfied: importlib-metadata>=0.12 in c:\miniconda\envs\udacity\lib\site-packages (from pytest==7.1.1->-r requirements.txt (line 11)) (6.7.0)
# Requirement already satisfied: pytz>=2017.3 in c:\miniconda\envs\udacity\lib\site-packages (from pandas==1.3.5->-r requirements.txt (line 12)) (2023.3)
# Requirement already satisfied: scipy>=1.0 in c:\miniconda\envs\udacity\lib\site-packages (from seaborn==0.11.2->-r requirements.txt (line 13)) (1.7.3)
# Requirement already satisfied: zipp>=0.5 in c:\miniconda\envs\udacity\lib\site-packages (from importlib-metadata>=0.12->pytest==7.1.1->-r requirements.txt (line 11)) (3.15.0)
# Requirement already satisfied: psutil in c:\miniconda\envs\udacity\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (5.9.5)
# Requirement already satisfied: debugpy>=1.0 in c:\miniconda\envs\udacity\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.6.7)
# Requirement already satisfied: nest-asyncio in c:\miniconda\envs\udacity\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.5.7)
# Requirement already satisfied: pyzmq>=17 in c:\miniconda\envs\udacity\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (24.0.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\miniconda\envs\udacity\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.1.6)
# Requirement already satisfied: jupyter-client>=6.1.12 in c:\miniconda\envs\udacity\lib\site-packages (from ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (7.4.9)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\miniconda\envs\udacity\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (3.0.39)
# Requirement already satisfied: backcall in c:\miniconda\envs\udacity\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.0)
# Requirement already satisfied: decorator in c:\miniconda\envs\udacity\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\miniconda\envs\udacity\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.19.0)
# Requirement already satisfied: pygments in c:\miniconda\envs\udacity\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.15.1)
# Requirement already satisfied: pickleshare in c:\miniconda\envs\udacity\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in c:\miniconda\envs\udacity\lib\site-packages (from ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (65.6.3)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\miniconda\envs\udacity\lib\site-packages (from Jinja2>=2.7->bokeh==2.1.1->-r requirements.txt (line 5)) (2.1.3)
# Requirement already satisfied: jupyter-core in c:\miniconda\envs\udacity\lib\site-packages (from nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (4.12.0)
# Requirement already satisfied: fastjsonschema in c:\miniconda\envs\udacity\lib\site-packages (from nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.18.0)
# Requirement already satisfied: jsonschema>=2.6 in c:\miniconda\envs\udacity\lib\site-packages (from nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (4.17.3)
# Requirement already satisfied: six>=1.5 in c:\miniconda\envs\udacity\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.4.3->-r requirements.txt (line 2)) (1.16.0)
# Requirement already satisfied: notebook>=4.4.1 in c:\miniconda\envs\udacity\lib\site-packages (from widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (6.5.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\miniconda\envs\udacity\lib\site-packages (from requests->torchvision==0.12.0->-r requirements.txt (line 7)) (1.26.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\miniconda\envs\udacity\lib\site-packages (from requests->torchvision==0.12.0->-r requirements.txt (line 7)) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\miniconda\envs\udacity\lib\site-packages (from requests->torchvision==0.12.0->-r requirements.txt (line 7)) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\miniconda\envs\udacity\lib\site-packages (from requests->torchvision==0.12.0->-r requirements.txt (line 7)) (3.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\miniconda\envs\udacity\lib\site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.8.3)
# Requirement already satisfied: pkgutil-resolve-name>=1.3.10 in c:\miniconda\envs\udacity\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.3.10)
# Requirement already satisfied: importlib-resources>=1.4.0 in c:\miniconda\envs\udacity\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (5.12.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\miniconda\envs\udacity\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.19.3)
# Requirement already satisfied: entrypoints in c:\miniconda\envs\udacity\lib\site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.4)
# Requirement already satisfied: pywin32>=1.0 in c:\miniconda\envs\udacity\lib\site-packages (from jupyter-core->nbformat>=4.2.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (306)
# Requirement already satisfied: Send2Trash>=1.8.0 in c:\miniconda\envs\udacity\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.8.2)
# Requirement already satisfied: nbconvert>=5 in c:\miniconda\envs\udacity\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (7.6.0)
# Requirement already satisfied: prometheus-client in c:\miniconda\envs\udacity\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.17.1)
# Requirement already satisfied: nbclassic>=0.4.7 in c:\miniconda\envs\udacity\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.0.0)
# Requirement already satisfied: terminado>=0.8.3 in c:\miniconda\envs\udacity\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.17.1)
# Requirement already satisfied: argon2-cffi in c:\miniconda\envs\udacity\lib\site-packages (from notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (21.3.0)
# Requirement already satisfied: wcwidth in c:\miniconda\envs\udacity\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.6)
# Requirement already satisfied: notebook-shim>=0.2.3 in c:\miniconda\envs\udacity\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.3)
# Requirement already satisfied: jupyter-server>=1.8 in c:\miniconda\envs\udacity\lib\site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.24.0)
# Requirement already satisfied: jupyterlab-pygments in c:\miniconda\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.2.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\miniconda\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (6.0.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\miniconda\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.5.0)
# Requirement already satisfied: tinycss2 in c:\miniconda\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.2.1)
# Requirement already satisfied: nbclient>=0.5.0 in c:\miniconda\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.7.4)
# Requirement already satisfied: defusedxml in c:\miniconda\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.7.1)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\miniconda\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (3.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\miniconda\envs\udacity\lib\site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (4.12.2)
# Requirement already satisfied: pywinpty>=1.1.0 in c:\miniconda\envs\udacity\lib\site-packages (from terminado>=0.8.3->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.0.10)
# Requirement already satisfied: argon2-cffi-bindings in c:\miniconda\envs\udacity\lib\site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (21.2.0)
# Requirement already satisfied: webencodings in c:\miniconda\envs\udacity\lib\site-packages (from bleach!=5.0.0->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (0.5.1)
# Requirement already satisfied: websocket-client in c:\miniconda\envs\udacity\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.6.1)
# Requirement already satisfied: anyio<4,>=3.1.0 in c:\miniconda\envs\udacity\lib\site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (3.7.1)
# Requirement already satisfied: cffi>=1.0.1 in c:\miniconda\envs\udacity\lib\site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.15.1)
# Requirement already satisfied: soupsieve>1.2 in c:\miniconda\envs\udacity\lib\site-packages (from beautifulsoup4->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.4.1)
# Requirement already satisfied: exceptiongroup in c:\miniconda\envs\udacity\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.1.2)
# Requirement already satisfied: sniffio>=1.1 in c:\miniconda\envs\udacity\lib\site-packages (from anyio<4,>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (1.3.0)
# Requirement already satisfied: pycparser in c:\miniconda\envs\udacity\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.5.0->ipywidgets==7.6.5->-r requirements.txt (line 9)) (2.21)

# %%
from src.helpers import setup_env

# If running locally, this will download dataset (make sure you have at 
# least 2 Gb of space on your hard drive)
setup_env()
# Out:
# GPU available
# Dataset already downloaded. If you need to re-download, please delete the directory landmark_images

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 1: Create transfer learning architecture
#
# Open the file `src/transfer.py` and complete the `get_model_transfer_learning` function. When you are done, execute this test:

# %%
# !pytest -vv src/transfer.py
# Out:
# ============================= test session starts =============================
# platform win32 -- Python 3.7.6, pytest-7.1.1, pluggy-1.2.0 -- C:\MiniConda\envs\udacity\python.exe
# cachedir: .pytest_cache
# rootdir: C:\workspace
# plugins: anyio-3.7.1
# collecting ... collected 1 item
#
# src/transfer.py::test_get_model_transfer_learning PASSED                 [100%]
#
# ============================== warnings summary ===============================
# src/transfer.py::test_get_model_transfer_learning
# src/transfer.py::test_get_model_transfer_learning
# src/transfer.py::test_get_model_transfer_learning
# src/transfer.py::test_get_model_transfer_learning
# src/transfer.py::test_get_model_transfer_learning
#   C:\MiniConda\envs\udacity\lib\site-packages\matplotlib\__init__.py:152: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     if LooseVersion(module.__version__) < minver:
#
# src/transfer.py::test_get_model_transfer_learning
# src/transfer.py::test_get_model_transfer_learning
# src/transfer.py::test_get_model_transfer_learning
# src/transfer.py::test_get_model_transfer_learning
# src/transfer.py::test_get_model_transfer_learning
#   C:\MiniConda\envs\udacity\lib\site-packages\setuptools\_distutils\version.py:346: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#     other = LooseVersion(other)
#
# -- Docs: https://docs.pytest.org/en/stable/how-to/capture-warnings.html
# ======================= 1 passed, 10 warnings in 38.22s =======================

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 2: Train, validation and test
#
# Let's train our transfer learning model! Let's start defining the hyperparameters:

# %%
batch_size = 64  # size of the minibatch for stochastic gradient descent (or Adam)
valid_size = 0.2  # fraction of the training data to reserve for validation
num_epochs = 50  # number of epochs for training
num_classes = 50  # number of classes. Do not change this
learning_rate = 0.001  # Learning rate for SGD (or Adam)
opt = 'adam'      # optimizer. 'sgd' or 'adam'
weight_decay = 0.001 # regularization. Increase this to combat overfitting

# %%
from src.data import get_data_loaders
from src.optimization import get_optimizer, get_loss
from src.train import optimize
from src.transfer import get_model_transfer_learning

# Get a model using get_model_transfer_learning. Use one of the names reported here:
# https://pytorch.org/vision/0.10/models.html
# For example, if you want to load ResNet 18, use "resnet18"
# NOTE: use the hyperparameters defined in the previous cell, do NOT copy/paste the
# values
model_transfer = get_model_transfer_learning(model_name="resnet18", n_classes=num_classes)

# train the model
data_loaders = get_data_loaders(batch_size=batch_size)
optimizer = get_optimizer(
    model_transfer,
    learning_rate=learning_rate,
    optimizer=opt,
    weight_decay=weight_decay,
)
loss = get_loss()

optimize(
    data_loaders,
    model_transfer,
    optimizer,
    loss,
    n_epochs=num_epochs,
    save_path="checkpoints/model_transfer.pt",
    interactive_tracking=True
)
# Out:
# Training:   0%|                                          | 0/63 [00:02<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17156\294277677.py in <module>
#      28     n_epochs=num_epochs,
#      29     save_path="checkpoints/model_transfer.pt",
# ---> 30     interactive_tracking=True
#      31 )
#
# C:\workspace\src\train.py in optimize(data_loaders, model, optimizer, loss, n_epochs, save_path, interactive_tracking)
#     111
#     112         train_loss = train_one_epoch(
# --> 113             data_loaders["train"], model, optimizer, loss
#     114         )
#     115
#
# C:\workspace\src\train.py in train_one_epoch(train_dataloader, model, optimizer, loss)
#      37         # YOUR CODE HERE:
#      38         # 2. forward pass: compute predicted outputs by passing inputs to the model
# ---> 39         output = model(data)
#      40         # 3. calculate the loss
#      41         loss_value = loss(output, target)
#
# C:\MiniConda\envs\udacity\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# C:\MiniConda\envs\udacity\lib\site-packages\torchvision\models\resnet.py in forward(self, x)
#     281
#     282     def forward(self, x: Tensor) -> Tensor:
# --> 283         return self._forward_impl(x)
#     284
#     285
#
# C:\MiniConda\envs\udacity\lib\site-packages\torchvision\models\resnet.py in _forward_impl(self, x)
#     267         x = self.bn1(x)
#     268         x = self.relu(x)
# --> 269         x = self.maxpool(x)
#     270
#     271         x = self.layer1(x)
#
# C:\MiniConda\envs\udacity\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1108         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1109                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1110             return forward_call(*input, **kwargs)
#    1111         # Do not call functions when jit is used
#    1112         full_backward_hooks, non_full_backward_hooks = [], []
#
# C:\MiniConda\envs\udacity\lib\site-packages\torch\nn\modules\pooling.py in forward(self, input)
#     162         return F.max_pool2d(input, self.kernel_size, self.stride,
#     163                             self.padding, self.dilation, self.ceil_mode,
# --> 164                             self.return_indices)
#     165
#     166
#
# C:\MiniConda\envs\udacity\lib\site-packages\torch\_jit_internal.py in fn(*args, **kwargs)
#     420             return if_true(*args, **kwargs)
#     421         else:
# --> 422             return if_false(*args, **kwargs)
#     423
#     424     if if_true.__doc__ is None and if_false.__doc__ is not None:
#
# C:\MiniConda\envs\udacity\lib\site-packages\torch\nn\functional.py in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     795     if stride is None:
#     796         stride = torch.jit.annotate(List[int], [])
# --> 797     return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#     798
#     799
#
# KeyboardInterrupt:

# %% [markdown]
# <img src="static_images/icons/noun-question-mark-869751.png" alt="?" style="width:25px"/> __Question:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.

# %% [markdown]
# <img src="static_images/icons/noun-answer-3361020.png" alt=">" style="width:25px"/>  __Answer:__ I decided to use ResNet18 for the base of my model, since it performs fairly well on ImageNet and is not too large of a model. Also, since ResNet18 was trained for the ImageNet task, it is a good model to use for this landmark classificaiton task, since both ImageNet and this landmark task use images of natural scenes.

# %% [markdown]
# Now play with the hyperparameters and see which performance you can get on the validation set. You should get at least 60% for a passing grade, but a good model choice and a good training strategy could get you up to 80% or so. Let's see how close you can get!

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 3: Test the Model
#
# Try out your model on the test dataset of landmark images. Use the code cell below to calculate and print the test loss and accuracy.  Ensure that your test accuracy is greater than 60% and matches more or less what you got on the validation set (otherwise you're overfitting!)

# %%
import torch
from src.train import one_epoch_test
from src.transfer import get_model_transfer_learning

model_transfer = get_model_transfer_learning("resnet18", n_classes=num_classes)
# Load saved weights
model_transfer.load_state_dict(torch.load('checkpoints/model_transfer.pt'))

one_epoch_test(data_loaders['test'], model_transfer, loss)
# Out:
# Testing: 100%|██████████████████████████████████| 20/20 [01:25<00:00,  4.27s/it]
# Test Loss: 0.956936
#
#
# Test Accuracy: 75% (947/1250)
# 0.9569363772869109

# %% [markdown]
# ---
# ## <img src="static_images/icons/noun-advance-2109145.png" alt=">" style="width:50px"/> Step 4: Export using torchscript
#
# Now, just like we did with our original model, we export the best fit model using torchscript so that it can be used in our application:

# %%
from src.predictor import Predictor
from src.helpers import compute_mean_and_std

# First let's get the class names from our data loaders
class_names = data_loaders["train"].dataset.classes

# Then let's move the model_transfer to the CPU
# (we don't need GPU for inference)
model_transfer = model_transfer.cpu()
# Let's make sure we use the right weights by loading the
# best weights we have found during training
# NOTE: remember to use map_location='cpu' so the weights
# are loaded on the CPU (and not the GPU)
model_transfer.load_state_dict(
    torch.load("checkpoints/model_transfer.pt", map_location="cpu")
)

# Let's wrap our model using the predictor class
mean, std = compute_mean_and_std()
predictor = Predictor(model_transfer, class_names, mean, std).cpu()

# Export using torch.jit.script
scripted_predictor = torch.jit.script(predictor)
scripted_predictor.save("checkpoints/transfer_exported.pt")
# Out:
# Reusing cached mean and std

# %%
import torch
from src.predictor import predictor_test
from src.helpers import plot_confusion_matrix

model_reloaded = torch.jit.load("checkpoints/transfer_exported.pt")

pred, truth = predictor_test(data_loaders['test'], model_reloaded)

plot_confusion_matrix(pred, truth)
# Out:
# 100%|███████████████████████████████████████| 1250/1250 [02:12<00:00,  9.42it/s]
# Accuracy: 0.7568
